# %% [markdown]
# <h3> CAR-PRICE-PREDICTION USING REGRESSION </H3>

# %% [markdown]
# <h3><u>Dataset collection</u> </h3>
# <h3>-I got my Dataset "cars24dataset" from Kaggels.</h3>
# <h3>-cars24dataset contains details about old cars.</h3>

# %% [markdown]
# <h3><u>Problem Statement:</u>
# The used car market is growing rapidly, and pricing can be influenced by numerous features. Manually estimating car prices is prone to error and bias. Machine learning provides a scalable and data-driven approach to accurately estimate car prices.</h3>

# %% [markdown]
# <h3><u></u>Objective</u></h3>
#
# - Clean and preprocess the car data.
# - Perform exploratory data analysis (EDA).
# - Build and evaluate regression models for accurate price prediction.
# -Interpret the model outputs and identify key influencing features.

# %% [markdown]
# <h3><u>Dataset Description</u></h3>
#
# -Source: Dataset loaded from 'cars24data.csv'.
# -Target Variable: Selling_Price
#
# -Features: Name, Year, Kilometers Driven, Fuel Type, Transmission, Owner, Mileage, Engine, Power, Seats.

# %% [markdown]
# <h3>importing libraries</h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('cars24data.csv')

# %%
df
# Out:
#                                Model Name    Price  Manufacturing_year  \
# 0                   2017 Maruti Swift VXI   561000                2017
# 1     2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                   2020 Maruti Swift VXI   577000                2020
# 3          2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                   2019 Maruti Dzire VXI   603000                2019
# ...                                   ...      ...                 ...
# 1440          2021 Maruti Ertiga VXI SHVS   862000                2021
# 1441                 2015 Maruti Ciaz ZXI   507000                2015
# 1442  2019 Maruti Baleno DELTA PETROL 1.2   554000                2019
# 1443     2017 Maruti Ciaz S 1.4 MT PETROL   557000                2017
# 1444          2012 Maruti Wagon R 1.0 LXI   256000                2012
#
#       Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0                1197        No       Manual      25847          2    Petrol
# 1                1197       Yes       Manual      55511          2    Petrol
# 2                1197        No       Manual      47110          1    Petrol
# 3                1462       Yes    Automatic      35378          1    Petrol
# 4                1197       Yes       Manual      91856          1    Petrol
# ...               ...       ...          ...        ...        ...       ...
# 1440             1462        No       Manual      19901          1    Petrol
# 1441             1373        No       Manual      50022          1    Petrol
# 1442             1197       Yes       Manual      58679          1    Petrol
# 1443             1373       Yes       Manual      73948          2    Petrol
# 1444              998        No       Manual      55994          1    Petrol
#
#       Imperfections  Repainted Parts
# 0                 6                2
# 1                12                1
# 2                 4                2
# 3                 2                3
# 4                 3                2
# ...             ...              ...
# 1440              1                0
# 1441              5                2
# 1442             24                4
# 1443              4                5
# 1444             20                9
#
# [1445 rows x 11 columns]

# %%
# View the first 5 rows
print(df.head())

# Shape of the dataset
print("Shape of dataset:", df.shape)

# Info about datatypes and nulls
df.info()

# Summary statistics
df.describe()
# Out:
#                             Model Name    Price  Manufacturing_year  \
# 0                2017 Maruti Swift VXI   561000                2017
# 1  2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                2020 Maruti Swift VXI   577000                2020
# 3       2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                2019 Maruti Dzire VXI   603000                2019
#
#    Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0             1197        No       Manual      25847          2    Petrol
# 1             1197       Yes       Manual      55511          2    Petrol
# 2             1197        No       Manual      47110          1    Petrol
# 3             1462       Yes    Automatic      35378          1    Petrol
# 4             1197       Yes       Manual      91856          1    Petrol
#
#    Imperfections  Repainted Parts
# 0              6                2
# 1             12                1
# 2              4                2
# 3              2                3
# 4              3                2
# Shape of dataset: (1445, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Model Name          1445 non-null   object
#  1   Price               1445 non-null   int64
#  2   Manufacturing_year  1445 non-null   int64
#  3   Engine capacity     1445 non-null   int64
#  4   Spare key           1445 non-null   object
#  5   Transmission        1445 non-null   object
#  6   KM driven           1445 non-null   int64
#  7   Ownership           1445 non-null   int64
#  8   Fuel type           1445 non-null   object
#  9   Imperfections       1445 non-null   int64
#  10  Repainted Parts     1445 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 124.3+ KB
#               Price  Manufacturing_year  Engine capacity      KM driven  \
# count  1.445000e+03         1445.000000      1445.000000    1445.000000
# mean   5.263543e+05         2017.817301      1142.104498   50588.903114
# std    1.963696e+05            2.986554       169.020818   27339.562631
# min    1.390000e+05         2010.000000       796.000000    1207.000000
# 25%    3.900000e+05         2016.000000       998.000000   28803.000000
# 50%    5.010000e+05         2018.000000      1197.000000   47849.000000
# 75%    6.310000e+05         2020.000000      1197.000000   70337.000000
# max    1.599000e+06         2023.000000      1462.000000  124716.000000
#
#          Ownership  Imperfections  Repainted Parts
# count  1445.000000    1445.000000      1445.000000
# mean      1.285121       9.597232         3.228374
# std       0.489877       8.398637         3.364578
# min       1.000000       0.000000         0.000000
# 25%       1.000000       3.000000         0.000000
# 50%       1.000000       8.000000         2.000000
# 75%       2.000000      14.000000         5.000000
# max       3.000000      43.000000        27.000000

# %%
# Count missing values
print(df.isnull().sum())
# Out:
# Model Name            0
# Price                 0
# Manufacturing_year    0
# Engine capacity       0
# Spare key             0
# Transmission          0
# KM driven             0
# Ownership             0
# Fuel type             0
# Imperfections         0
# Repainted Parts       0
# dtype: int64

# %%
# duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# unique
df.nunique()
# Out:
# Model Name             573
# Price                  598
# Manufacturing_year      14
# Engine capacity          7
# Spare key                2
# Transmission             2
# KM driven             1439
# Ownership                3
# Fuel type                3
# Imperfections           42
# Repainted Parts         21
# dtype: int64

# %%
#univariable analysis

# %%
# Define categorical columns for pie charts
categorical_columns = ['Spare key', 'Transmission', 'Ownership', 'Fuel type']

# Set up the figure for pie charts
fig, axs = plt.subplots(2, 2, figsize=(7, 5))
axs = axs.flatten()

# Plot a pie chart for each categorical column
for i, column in enumerate(categorical_columns):
    counts = df[column].value_counts()
    axs[i].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
    axs[i].set_title(f'{column} Distribution')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
# Example for numerical columns
df.hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# For categorical features
print(df['Fuel type'].value_counts())
sns.countplot(data=df, x='Fuel type')
plt.show()
# Out:
# Fuel type
# Petrol    1264
# CNG        109
# Diesel      72
# Name: count, dtype: int64

# %%
# Bivariate analysis

# %%
# Create a scatter plot of Price vs. KM driven
plt.figure(figsize=(10, 6))
plt.scatter(df['KM driven'], df['Price'], alpha=0.6)
plt.title('Price vs. KM Driven')
plt.xlabel('KM Driven')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Price vs Year
sns.scatterplot(data=df, x='Manufacturing_year', y='Price')
plt.title("Price vs ManifacturingYear")
plt.show()

# %%
# Price vs Fuel Type
sns.boxplot(data=df, x='Fuel type', y='Price')
plt.title("Price Distribution by Fuel Type")
plt.show()

# %%
# Select only numeric columns
numeric_cols = df.select_dtypes(include='number')

# Calculate IQR
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

# Filter out outliers
df_no_outliers = df[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Original shape:", df.shape)
print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original shape: (1445, 11)
# After removing outliers: (1341, 11)

# %%
df_cleaned = df_no_outliers

# %%
# Drop 'Model Name' if you want to ignore it due to high cardinality
df_cleaned = df_cleaned.drop(columns=['Model Name','Spare key'])

# %% [markdown]
# <h2> label encoding </h2>

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
le = LabelEncoder()
df_cleaned['Transmission'] = le.fit_transform(df_cleaned['Transmission'])

# %%
df_cleaned['Transmission']
# Out:
# 0       1
# 1       1
# 2       1
# 4       1
# 5       1
#        ..
# 1440    1
# 1441    1
# 1442    1
# 1443    1
# 1444    1
# Name: Transmission, Length: 1341, dtype: int64

# %%
df_cleaned
# Out:
#        Price  Manufacturing_year  Engine capacity  Transmission  KM driven  \
# 0     561000                2017             1197             1      25847
# 1     498000                2016             1197             1      55511
# 2     577000                2020             1197             1      47110
# 4     603000                2019             1197             1      91856
# 5     233000                2014              796             1      43780
# ...      ...                 ...              ...           ...        ...
# 1440  862000                2021             1462             1      19901
# 1441  507000                2015             1373             1      50022
# 1442  554000                2019             1197             1      58679
# 1443  557000                2017             1373             1      73948
# 1444  256000                2012              998             1      55994
#
#       Ownership Fuel type  Imperfections  Repainted Parts
# 0             2    Petrol              6                2
# 1             2    Petrol             12                1
# 2             1    Petrol              4                2
# 4             1    Petrol              3                2
# 5             1    Petrol             10                2
# ...         ...       ...            ...              ...
# 1440          1    Petrol              1                0
# 1441          1    Petrol              5                2
# 1442          1    Petrol             24                4
# 1443          2    Petrol              4                5
# 1444          1    Petrol             20                9
#
# [1341 rows x 9 columns]

# %%
# one hot encoding
df_encoded = pd.get_dummies(df_cleaned, columns=['Fuel type'], prefix='Fuel type')
df_encoded = df_encoded.astype(int)  # Force to 0/1

# %%
df_encoded
# Out:
#        Price  Manufacturing_year  Engine capacity  Transmission  KM driven  \
# 0     561000                2017             1197             1      25847
# 1     498000                2016             1197             1      55511
# 2     577000                2020             1197             1      47110
# 4     603000                2019             1197             1      91856
# 5     233000                2014              796             1      43780
# ...      ...                 ...              ...           ...        ...
# 1440  862000                2021             1462             1      19901
# 1441  507000                2015             1373             1      50022
# 1442  554000                2019             1197             1      58679
# 1443  557000                2017             1373             1      73948
# 1444  256000                2012              998             1      55994
#
#       Ownership  Imperfections  Repainted Parts  Fuel type_CNG  \
# 0             2              6                2              0
# 1             2             12                1              0
# 2             1              4                2              0
# 4             1              3                2              0
# 5             1             10                2              0
# ...         ...            ...              ...            ...
# 1440          1              1                0              0
# 1441          1              5                2              0
# 1442          1             24                4              0
# 1443          2              4                5              0
# 1444          1             20                9              0
#
#       Fuel type_Diesel  Fuel type_Petrol
# 0                    0                 1
# 1                    0                 1
# 2                    0                 1
# 4                    0                 1
# 5                    0                 1
# ...                ...               ...
# 1440                 0                 1
# 1441                 0                 1
# 1442                 0                 1
# 1443                 0                 1
# 1444                 0                 1
#
# [1341 rows x 11 columns]

# %%
df_cleaned=df_encoded

# %%
# Compute correlation matrix
correlation_matrix = df_cleaned.corr()

print(correlation_matrix)
# Out:
#                        Price  Manufacturing_year  Engine capacity  \
# Price               1.000000            0.577425         0.698394
# Manufacturing_year  0.577425            1.000000         0.045295
# Engine capacity     0.698394            0.045295         1.000000
# Transmission       -0.244243           -0.143244        -0.072432
# KM driven          -0.255904           -0.510780         0.076298
# Ownership          -0.170112           -0.203981        -0.040658
# Imperfections      -0.163182           -0.251138         0.004758
# Repainted Parts    -0.109670           -0.172681         0.039563
# Fuel type_CNG      -0.097093            0.038082        -0.185287
# Fuel type_Diesel    0.109693           -0.173350         0.159851
# Fuel type_Petrol    0.008678            0.079899         0.048189
#
#                     Transmission  KM driven  Ownership  Imperfections  \
# Price                  -0.244243  -0.255904  -0.170112      -0.163182
# Manufacturing_year     -0.143244  -0.510780  -0.203981      -0.251138
# Engine capacity        -0.072432   0.076298  -0.040658       0.004758
# Transmission            1.000000   0.056177  -0.041118       0.036036
# KM driven               0.056177   1.000000   0.179159       0.208655
# Ownership              -0.041118   0.179159   1.000000       0.019328
# Imperfections           0.036036   0.208655   0.019328       1.000000
# Repainted Parts         0.011149   0.213623   0.054535       0.401026
# Fuel type_CNG           0.161266   0.126386  -0.008261      -0.015632
# Fuel type_Diesel        0.076389   0.257904   0.069924       0.034169
# Fuel type_Petrol       -0.179698  -0.267416  -0.037991      -0.009155
#
#                     Repainted Parts  Fuel type_CNG  Fuel type_Diesel  \
# Price                     -0.109670      -0.097093          0.109693
# Manufacturing_year        -0.172681       0.038082         -0.173350
# Engine capacity            0.039563      -0.185287          0.159851
# Transmission               0.011149       0.161266          0.076389
# KM driven                  0.213623       0.126386          0.257904
# Ownership                  0.054535      -0.008261          0.069924
# Imperfections              0.401026      -0.015632          0.034169
# Repainted Parts            1.000000      -0.010085          0.022530
# Fuel type_CNG             -0.010085       1.000000         -0.064713
# Fuel type_Diesel           0.022530      -0.064713          1.000000
# Fuel type_Petrol          -0.006216      -0.770158         -0.586677
#
#                     Fuel type_Petrol
# Price                       0.008678
# Manufacturing_year          0.079899
# Engine capacity             0.048189
# Transmission               -0.179698
# KM driven                  -0.267416
# Ownership                  -0.037991
# Imperfections              -0.009155
# Repainted Parts            -0.006216
# Fuel type_CNG              -0.770158
# Fuel type_Diesel           -0.586677
# Fuel type_Petrol            1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_cleaned.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# View the new columns created
print(df_cleaned.columns)
# Out:
# Index(['Price', 'Manufacturing_year', 'Engine capacity', 'Transmission',
#        'KM driven', 'Ownership', 'Imperfections', 'Repainted Parts',
#        'Fuel type_CNG', 'Fuel type_Diesel', 'Fuel type_Petrol'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['Model Name', 'Price', 'Manufacturing_year', 'Engine capacity', 'Spare key', 'Transmission', 'KM driven', 'Ownership', 'Fuel type', 'Imperfections', 'Repainted Parts']

# %% [markdown]
# <h2> Assigning the X and Y values </h2>

# %%
x=df_cleaned.drop('Price',axis=1)
y=df_cleaned['Price']

# %%
print(x.shape)
print(y.shape)
# Out:
# (1341, 10)
# (1341,)

# %%
df_cleaned
# Out:
#        Price  Manufacturing_year  Engine capacity  Transmission  KM driven  \
# 0     561000                2017             1197             1      25847
# 1     498000                2016             1197             1      55511
# 2     577000                2020             1197             1      47110
# 4     603000                2019             1197             1      91856
# 5     233000                2014              796             1      43780
# ...      ...                 ...              ...           ...        ...
# 1440  862000                2021             1462             1      19901
# 1441  507000                2015             1373             1      50022
# 1442  554000                2019             1197             1      58679
# 1443  557000                2017             1373             1      73948
# 1444  256000                2012              998             1      55994
#
#       Ownership  Imperfections  Repainted Parts  Fuel type_CNG  \
# 0             2              6                2              0
# 1             2             12                1              0
# 2             1              4                2              0
# 4             1              3                2              0
# 5             1             10                2              0
# ...         ...            ...              ...            ...
# 1440          1              1                0              0
# 1441          1              5                2              0
# 1442          1             24                4              0
# 1443          2              4                5              0
# 1444          1             20                9              0
#
#       Fuel type_Diesel  Fuel type_Petrol
# 0                    0                 1
# 1                    0                 1
# 2                    0                 1
# 4                    0                 1
# 5                    0                 1
# ...                ...               ...
# 1440                 0                 1
# 1441                 0                 1
# 1442                 0                 1
# 1443                 0                 1
# 1444                 0                 1
#
# [1341 rows x 11 columns]

# %%
# to train the model in regression(linear).
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1072, 10)
# (269, 10)
# (1072,)
# (269,)

# %%
x_train
# Out:
#       Manufacturing_year  Engine capacity  Transmission  KM driven  Ownership  \
# 880                 2017              998             1      81370          1
# 1392                2014              998             1      53063          2
# 642                 2021             1197             1      25742          1
# 1052                2019             1197             1      54029          1
# 962                 2019              998             0      70604          1
# ...                  ...              ...           ...        ...        ...
# 1189                2016              998             1      19613          2
# 1226                2019             1197             0      16416          2
# 1398                2015             1196             1      48661          1
# 931                 2013              998             1      66819          1
# 1222                2016              998             0      62447          1
#
#       Imperfections  Repainted Parts  Fuel type_CNG  Fuel type_Diesel  \
# 880               4               11              1                 0
# 1392             11                5              0                 0
# 642               6                4              0                 0
# 1052             14                3              0                 0
# 962              14                9              0                 0
# ...             ...              ...            ...               ...
# 1189             12                7              0                 0
# 1226              7                0              0                 0
# 1398              7                1              1                 0
# 931              21                8              0                 0
# 1222             11                1              0                 0
#
#       Fuel type_Petrol
# 880                  0
# 1392                 1
# 642                  1
# 1052                 1
# 962                  1
# ...                ...
# 1189                 1
# 1226                 1
# 1398                 0
# 931                  1
# 1222                 1
#
# [1072 rows x 10 columns]

# %% [markdown]
# <h2> applying scalar </h2>

# %%
# applying standard scalar
from sklearn.preprocessing import StandardScaler
# useing scaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.29248361, -0.82168926,  0.59746299, ...,  3.38601776,
#         -0.2280609 , -2.59079722],
#        [-1.33185076, -0.82168926,  0.59746299, ..., -0.29533218,
#         -0.2280609 ,  0.38598158],
#        [ 1.09333927,  0.41078974,  0.59746299, ..., -0.29533218,
#         -0.2280609 ,  0.38598158],
#        ...,
#        [-0.98539504,  0.40459638,  0.59746299, ...,  3.38601776,
#         -0.2280609 , -2.59079722],
#        [-1.67830648, -0.82168926,  0.59746299, ..., -0.29533218,
#         -0.2280609 ,  0.38598158],
#        [-0.63893932, -0.82168926, -1.67374384, ..., -0.29533218,
#         -0.2280609 ,  0.38598158]], shape=(1072, 10))

# %% [markdown]
# <h1>1.stocastic gradient descent</h1>

# %%
# SGD---
from sklearn.linear_model import SGDRegressor
print("\n--- SGD Method ---")
sgd_model=SGDRegressor(max_iter=1000,tol=1e-3,eta0=0.01,random_state=42)# max_iter=1000,eta=0.01 is default  
sgd_model.fit(x_train_scaled,y_train)
# Out:
# --- SGD Method ---
# SGDRegressor(random_state=42)

# %%
# we have to predict TRAIN on ypre_train WITH X_TRAIN_SCALED
Ypre_train=sgd_model.predict(x_train_scaled)
print(Ypre_train)
# Out:
# [392347.7772185  282306.82369573 640450.3967118  ... 487688.84951846
#  256121.53468766 404802.56821149]

# %%
# we have to predict TEST on ypre_train WITH X_TEST_SCALED
Ypre_test=sgd_model.predict(x_test_scaled)

# %%
# to print the column name and coefficient we use("enumeprintrate")
for idx,col_name in enumerate(x_train.columns):
    print("the coefficient for {} is {}".format(col_name,sgd_model.coef_[idx]))
# Out:
# the coefficient for Manufacturing_year is 82295.16303198204
# the coefficient for Engine capacity is 107698.53766610725
# the coefficient for Transmission is -22672.29745297268
# the coefficient for KM driven is -9720.13346161892
# the coefficient for Ownership is -6650.534588907046
# the coefficient for Imperfections is -2475.080374618863
# the coefficient for Repainted Parts is -2829.110583534106
# the coefficient for Fuel type_CNG is -572.5386171456544
# the coefficient for Fuel type_Diesel is 14608.252918952983
# the coefficient for Fuel type_Petrol is -8964.073405715028

# %% [markdown]
# # summary
# .coef_ gives you the weights learned by SGD.
# You pair them with column names to understand feature importance and direction.
# This is essential for model interpretation in linear models like SGDRegressor.

# %%
# model evaluation measures:(test data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_sgd=mean_squared_error(y_test,Ypre_test) # MSE
# root mean square error
rmse_sgd=np.sqrt(mse_sgd) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_sgd=r2_score(y_test,Ypre_test) #R-square

# %%
print(mse_sgd)
# Out:
# 3903519751.096739

# %%
rmse_sgd
# Out:
# np.float64(62478.15419085889)

# %%
r2_sgd
# Out:
# 0.8353780185124635

# %%
# Adjusted r2
# 1-(1-r2)*(n-1)/(n-k-1)

# r2 - COFFICIENT OF DETERMENT
# n - number of observation or data points
# K - numbers of independent variables( x variables)

adj_r2_sgd=1-(1-r2_sgd)*((len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
adj_r2_sgd
# Out:
# 0.8289973215555823

# %%
# train data

# Evaluation metrics for training data
mse_train = mean_squared_error(y_train, Ypre_train)
rmse_train = np.sqrt(mse_train)
r2_train = r2_score(y_train, Ypre_train)

# Print the results
print("Training Set Evaluation:")
print(f"MSE: {mse_train}")
print(f"RMSE: {rmse_train}")
print(f"R² Score: {r2_train}")
# Out:
# Training Set Evaluation:
# MSE: 4917583757.49813
# RMSE: 70125.48579153039
# R² Score: 0.8156403721371697

# %%
# train data

# Adjusted r2
# 1-(1-r2)*(n-1)/(n-k-1)

# r2 - COFFICIENT OF DETERMENT
# n - number of observation or data points
# K - numbers of independent variables( x variables)

adj_r2_sgd=1-(1-r2_sgd)*((len(y_train)-1)/(len(y_train)-x_train.shape[1]-1))
adj_r2_sgd
# Out:
# 0.8338264447001399

# %%
# Coefficients of the model
coefficients = sgd_model.coef_

# Print the coefficients for each feature
for feature, coef in zip(x.columns, coefficients):
    print(f'{feature}: {coef}')
# Out:
# Manufacturing_year: 82295.16303198204
# Engine capacity: 107698.53766610725
# Transmission: -22672.29745297268
# KM driven: -9720.13346161892
# Ownership: -6650.534588907046
# Imperfections: -2475.080374618863
# Repainted Parts: -2829.110583534106
# Fuel type_CNG: -572.5386171456544
# Fuel type_Diesel: 14608.252918952983
# Fuel type_Petrol: -8964.073405715028

# %%
# visualization

import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
plt.scatter(y_test, Ypre_test, color='blue', alpha=0.6)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Ideal line
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h1> Decision tree </h1>

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
# Build and train the decision tree Regressor
dtr_model=DecisionTreeRegressor(random_state=42)
dtr_model.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# we have to predict TRAIN on ypre_train WITH X_TRAIN_SCALED
Ypre_train=dtr_model.predict(x_train_scaled)
print(Ypre_train)
# Out:
# [356000. 326000. 479000. ... 381000. 319000. 442000.]

# %%
from sklearn.model_selection import GridSearchCV

# %%
# HYPERPARAMETER TUNING.
param_grid={
    'max_depth':[3,5,10,None],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
}
# USING GridSearchCV (Cross validation).
grid_search=GridSearchCV(DecisionTreeRegressor(random_state=42),
                         param_grid,cv=5,scoring='neg_mean_squared_error',
    n_jobs=-1,
    verbose=1)
grid_search.fit(x_train_scaled,y_train)

# Best model from grid search
best_dtr=grid_search.best_estimator_
y_pred_best=best_dtr.predict(x_test_scaled)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
# best model
best_model = grid_search.best_estimator_

# %%
# assigning
y_pred = best_model.predict(x_train_scaled)

# %%
# model evaluation measures:(train data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_dtr_model=mean_squared_error(y_train,y_pred) # MSE
# root mean square error
rmse_dtr_model=np.sqrt(mse_dtr_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_dtr_model=r2_score(y_train,y_pred) #R-square


# Print the results
print("Training Set Evaluation:")
print(f"MSE: {mse_dtr_model}")
print(f"RMSE: {rmse_dtr_model}")
print(f"R² Score: {r2_dtr_model}")
# Out:
# Training Set Evaluation:
# MSE: 4828932298.26455
# RMSE: 69490.51948477972
# R² Score: 0.8189639047580181

# %%
# adjsent r2 (train data model)
adj_r2_dtr_model=1-(1-r2_dtr_model)*((len(y_train)-1)/(len(y_train)-x_train_scaled.shape[1]-1))
adj_r2_dtr_model
# Out:
# 0.8172576267632774

# %%
# we have to predict TRAIN on ypre_train WITH X_TRAIN_SCALED
Ypre_test=dtr_model.predict(x_test_scaled)
print(Ypre_test)
# Out:
# [264000. 904000. 755000. 416000. 630000. 519000. 372000. 527000. 469000.
#  568000. 278000. 447000. 546000. 470000. 439000. 352000. 519000. 584000.
#  377000. 369000. 475000. 745000. 523000. 616000. 219000. 503000. 487000.
#  498000. 554000. 580000. 465000. 517000. 515000. 532000. 739000. 533000.
#  588000. 386000. 490000. 670000. 517000. 513000. 477000. 587000. 543000.
#  758000. 635000. 254000. 347000. 358000. 488000. 536000. 865000. 807000.
#  267000. 445000. 243000. 547000. 368000. 470000. 329000. 445000. 623000.
#  375000. 703000. 473000. 319000. 700000. 710000. 637000. 480000. 365000.
#  694000. 362000. 379000. 442000. 397000. 267000. 337000. 287000. 278000.
#  717000. 692000. 448000. 817000. 542000. 630000. 333000. 596000. 751000.
#  593000. 512000. 294000. 574000. 565000. 468000. 253000. 393000. 643000.
#  414000. 608000. 452000. 332000. 397000. 512000. 568000. 665000. 461000.
#  555000. 703000. 548000. 470000. 633000. 363000. 362000. 425000. 528000.
#  410000. 275000. 497000. 422000. 323000. 343000. 422000. 515000. 381000.
#  278000. 319000. 466000. 556000. 519000. 458000. 581000. 385000. 571000.
#  380000. 240000. 866000. 973000. 469000. 373000. 898000. 692000. 554000.
#  373000. 677000. 491000. 416000. 469000. 385000. 573000. 522000. 554000.
#  304000. 429000. 267000. 543000. 596000. 524000. 468000. 849000. 755000.
#  665000. 548000. 337000. 373000. 254000. 490000. 523000. 358000. 635000.
#  838000. 506000. 513000. 506000. 631000. 641000. 621000. 350000. 280000.
#  665000. 532000. 465000. 662000. 578000. 275000. 306000. 358000. 690000.
#  428000. 670000. 497000. 287000. 398000. 494000. 626000. 780000. 531000.
#  597000. 568000. 717000. 332000. 323000. 484000. 351000. 352000. 662000.
#  770000. 581000. 565000. 689000. 562000. 264000. 245000. 267000. 336000.
#  358000. 700000. 476000. 299000. 437000. 372000. 730000. 516000. 554000.
#  379000. 441000. 386000. 388000. 647000. 561000. 329000. 449000. 575000.
#  780000. 294000. 608000. 927000. 454000. 580000. 533000. 596000. 915000.
#  278000. 416000. 567000. 425000. 373000. 329000. 598000. 420000. 633000.
#  306000. 448000. 436000. 548000. 492000. 560000. 780000. 554000. 317000.
#  473000. 616000. 275000. 733000. 337000. 294000. 790000. 513000.]

# %%
# assigning
y_pred = best_model.predict(x_test_scaled)

# %%
# model evaluation measures:(test data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_dtr_model=mean_squared_error(y_test,y_pred) # MSE
# root mean square error
rmse_dtr_model=np.sqrt(mse_dtr_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_dtr_model_test=r2_score(y_test,y_pred) #R-square


# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_dtr_model}")
print(f"RMSE: {rmse_dtr_model}")
print(f"R² Score: {r2_dtr_model_test}")
# Out:
# Testing Set Evaluation:
# MSE: 4432207737.106823
# RMSE: 66574.82810422286
# R² Score: 0.8130818167778158

# %%
# adjescent r2 (test data model)
adj_r2_dtr_model=1-(1-r2_dtr_model_test)*((len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1))
adj_r2_dtr_model
# Out:
# 0.8058369259552505

# %%
import matplotlib.pyplot as plt

# %%
# plot the Decission tree
plt.figure(figsize=(18,15))
plot_tree(dtr_model,feature_names=x.columns,filled=True,label='all')
plt.title("Car Price Prediction")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h1> RANDOM FOREST REGRESSOR </h1>

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
# Build and train the Randomforestclasifier
rfr_model=RandomForestRegressor(random_state=20)
rfr_model.fit(x_train_scaled,y_train)
# Out:
# RandomForestRegressor(random_state=20)

# %%
# after the gridsearch cv .......

# %%
# HYPERPARAMETER TUNING.
param_grid={
    'max_depth':[3,5,10,None],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
}
# USING GridSearchCV (Cross validation).
grid_search=GridSearchCV(RandomForestRegressor(random_state=42),
                         param_grid,cv=5,scoring='neg_mean_squared_error',
    n_jobs=-1,
    verbose=1)
grid_search.fit(x_train_scaled,y_train)

# Best model from grid search
best_rfr=grid_search.best_estimator_
y_pred_best=best_rfr.predict(x_test_scaled)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
# best model
best_model_rfr = grid_search.best_estimator_

# %%
# assigning(train)
y_pred_rfr_train = best_model_rfr.predict(x_train_scaled)

# %%
y_pred_rfr_train
# Out:
# array([366266.95683142, 286320.62679394, 610824.97753775, ...,
#        371382.30531468, 277561.94297058, 406203.75656868], shape=(1072,))

# %%
# model evaluation measures:(train data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_rfr_model=mean_squared_error(y_train,y_pred_rfr_train) # MSE
# root mean square error
rmse_rfr_model=np.sqrt(mse_rfr_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_rfr_model=r2_score(y_train,y_pred_rfr_train) #R-square


# Print the results
print("Training Set Evaluation:")
print(f"MSE: {mse_rfr_model}")
print(f"RMSE: {rmse_rfr_model}")
print(f"R² Score: {r2_rfr_model}")
# Out:
# Training Set Evaluation:
# MSE: 2313352347.6044326
# RMSE: 48097.32162609923
# R² Score: 0.9132726967243485

# %%
# adj r2 (train)
adj_r2_rfr_model_train=1-(1-r2_rfr_model)*((len(y_train)-1)/(len(y_train)-x_train.shape[1]-1))
adj_r2_rfr_model_train
# Out:
# 0.9124552857603933

# %%
# assigning(test)
y_pred_rfr_test = best_model_rfr.predict(x_test_scaled)

# %%
y_pred_rfr_test
# Out:
# array([267034.39923703, 859288.36374981, 760219.17384675, 497082.70793033,
#        639426.71355169, 503006.14542238, 322491.98598081, 445843.22854913,
#        478362.22898295, 538323.84434065, 258944.31047866, 392413.50631649,
#        630129.9634901 , 444525.72189845, 470302.82178789, 343814.7109867 ,
#        536334.89931222, 606806.86122213, 395338.8002431 , 433165.38337621,
#        441849.47826971, 686917.95397706, 682228.16537552, 590916.47642039,
#        233757.39141195, 462927.54898288, 475539.8868094 , 515192.90224309,
#        685119.31981907, 614923.7569733 , 456149.27976664, 441283.40698104,
#        594957.34926983, 476228.7287565 , 647773.61930399, 626652.35177495,
#        571567.63015254, 398813.24674889, 513806.38867946, 600463.92293879,
#        458908.80488328, 501850.08447738, 463304.47482063, 605198.37543657,
#        538886.28198949, 723275.90359894, 655064.28405335, 245109.46367595,
#        344733.63905906, 312889.55899162, 477542.95022346, 552694.35832832,
#        873911.09814884, 780528.26556368, 287024.63433434, 390956.20280594,
#        339683.3003503 , 482438.70436973, 380785.61630825, 502952.55168887,
#        297561.37668732, 439103.37118463, 602174.51449516, 369681.10672846,
#        676706.1688081 , 507099.74626185, 338180.05966256, 557169.45119247,
#        884670.96336915, 553247.96249309, 569739.14908263, 295111.84048363,
#        592928.74055928, 290887.25934154, 402652.49635116, 397508.03906471,
#        428185.51155513, 283802.25933542, 332373.96440243, 333337.56125819,
#        261807.01206864, 802628.24213205, 599363.65270816, 480958.48357219,
#        714736.52562071, 606383.18436955, 675950.39617123, 287211.95657446,
#        613742.10261267, 634480.89673592, 606773.84110673, 636003.42232245,
#        354946.00221717, 565489.31270411, 614083.91279524, 569739.53721073,
#        246557.07398979, 433023.16231775, 609422.03201221, 376581.72689495,
#        597702.69381076, 476421.13594936, 361831.4345638 , 398852.56226826,
#        635482.39503664, 586545.33297508, 633528.77734065, 530779.68071089,
#        499337.86780713, 682321.32305053, 583423.65265457, 492813.96503167,
#        634184.66283863, 352896.53757354, 400335.30863524, 441377.47720405,
#        596068.66855296, 372153.03491988, 226932.97210601, 522217.72511984,
#        509204.3541855 , 401699.57876164, 481098.84886622, 506780.12802696,
#        533904.01681098, 428345.79731989, 272488.85741709, 319540.81053669,
#        575871.63822177, 597298.40758898, 526289.1170938 , 581536.60911044,
#        556400.11367727, 350341.31168831, 489178.48322524, 379994.73991617,
#        268120.66749491, 840924.38663461, 882236.86136834, 507670.85891974,
#        443180.36266035, 754339.39648183, 653605.61023084, 713547.54240204,
#        350729.3126636 , 579523.9393086 , 475747.97126728, 480745.86578248,
#        524025.24975347, 396775.65249655, 425470.42587787, 537545.3547002 ,
#        718464.5117574 , 285581.51975426, 444298.77094581, 289379.64283401,
#        544114.12606853, 588119.86990899, 568546.92417766, 436773.89604525,
#        792858.26562254, 780284.88440726, 614034.98847102, 624431.21164588,
#        412085.3545719 , 436020.66059797, 254232.07712749, 478636.38846833,
#        718521.72712832, 283614.82291159, 643452.42817822, 863152.39061021,
#        535024.37483599, 499743.68527484, 529055.84492767, 627182.54379585,
#        562285.97700635, 554671.15319367, 370311.57685092, 272085.63493842,
#        607829.86431693, 547714.25564961, 528484.85980294, 525598.19376232,
#        618866.97745555, 301582.27950496, 319353.26724664, 362383.43021385,
#        601715.05137387, 531584.68347844, 416432.51802016, 505956.84909152,
#        349548.45454421, 423288.91177209, 509215.34629315, 666176.08500001,
#        770764.65056986, 506587.93411084, 610682.58248804, 594025.30847262,
#        801926.70092244, 418894.89125091, 396882.77200312, 529529.9923068 ,
#        354611.85586689, 359412.64448683, 523944.44148971, 740809.88726306,
#        561241.77396761, 502104.83362716, 655981.00695577, 564458.72700635,
#        273179.46207533, 221279.01267655, 292274.51262272, 423578.14265287,
#        350340.0383325 , 750506.94663137, 567971.65527195, 284893.7115088 ,
#        429550.40415186, 373516.49596367, 650495.99926803, 516642.71384943,
#        706718.82015456, 412094.24009738, 392440.43422942, 405424.10615006,
#        411178.23637806, 568120.24771772, 598200.62662666, 371821.34068763,
#        582685.6120608 , 618256.62496502, 758266.50987562, 281616.60441339,
#        582539.2270912 , 826869.83631169, 480500.37692709, 618563.95057921,
#        564850.32534305, 598507.66959901, 880263.40870567, 280755.25520704,
#        474606.58480643, 523128.24415588, 434507.90716135, 392517.63241093,
#        337293.92410805, 667694.61087862, 353212.19267089, 639236.53652801,
#        308997.94658545, 473059.91071866, 457795.42200914, 586023.26424668,
#        619106.31005264, 542133.80088398, 770872.21861293, 599260.92122159,
#        374962.89587797, 521151.44425399, 606024.46051969, 264156.49098896,
#        666065.15608075, 414413.19816621, 275849.57308724, 658466.68191993,
#        631172.96329141])

# %%
# model evaluation measures:(test data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_rfr_model=mean_squared_error(y_test,y_pred_rfr_test) # MSE
# root mean square error
rmse_rfr_model=np.sqrt(mse_rfr_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_rfr_model=r2_score(y_test,y_pred_rfr_test) #R-square


# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_rfr_model}")
print(f"RMSE: {rmse_rfr_model}")
print(f"R² Score: {r2_rfr_model}")
# Out:
# Testing Set Evaluation:
# MSE: 3567942596.3862915
# RMSE: 59732.257586552776
# R² Score: 0.8495302143953875

# %%
# adj r2 (test)
adj_r2_rfr_model_test=1-(1-r2_rfr_model)*((len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1))
adj_r2_rfr_model_test
# Out:
# 0.8436980521626505

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h1>XG-BOOSTER  technique</h1>

# %% [markdown]
# <h3> XGBOOSTER </h3>

# %%
import xgboost as xgb
from xgboost import XGBRegressor

# %%
xgb_model = XGBRegressor(
    n_estimators=100,
    learning_rate=0.1,
    reg_lambda=1.0,              # L2 regularization (Ridge)
    reg_alpha=0.5,               # L1 regularization (Lasso)
    objective='reg:squarederror',  # Required for regression
    random_state=42
)

# %%
# Fit the model
xgb_model.fit(x_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# prediction evaluation(train)
y_pred_xgb_train=xgb_model.predict(x_train_scaled)

# %%
# model evaluation measures:(train data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_xgb_model=mean_squared_error(y_train,y_pred_xgb_train) # MSE
# root mean square error
rmse_xgb_model=np.sqrt(mse_xgb_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_xgb_model=r2_score(y_train,y_pred_xgb_train) #R-square


# Print the results
print("Training Set Evaluation:")
print(f"MSE: {mse_xgb_model}")
print(f"RMSE: {rmse_xgb_model}")
print(f"R² Score: {r2_xgb_model}")
# Out:
# Training Set Evaluation:
# MSE: 1169437312.0
# RMSE: 34197.03659675791
# R² Score: 0.956157922744751

# %%
# adj r2 (train)
adj_r2_xgb_model_train=1-(1-r2_xgb_model)*((len(y_train)-1)/(len(y_train)-x_train_scaled.shape[1]-1))
adj_r2_xgb_model_train
# Out:
# 0.9557447080675102

# %%
# prediction evaluation(test)
y_pred_xgb_test=xgb_model.predict(x_test_scaled)

# %%
# model evaluation measures:(test data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_xgb_model=mean_squared_error(y_test,y_pred_xgb_test) # MSE
# root mean square error
rmse_xgb_model=np.sqrt(mse_xgb_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_xgb_model=r2_score(y_test,y_pred_xgb_test) #R-square


# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_xgb_model}")
print(f"RMSE: {rmse_xgb_model}")
print(f"R² Score: {r2_xgb_model}")
# Out:
# Testing Set Evaluation:
# MSE: 3817820672.0
# RMSE: 61788.51569668914
# R² Score: 0.838992178440094

# %%
# adj r2
# adj r2 (test)
adj_r2_xgb_model_test=1-(1-r2_xgb_model)*((len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1))
adj_r2_xgb_model_test
# Out:
# 0.832751565201338

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h2> Support vector machine </h2>

# %%
from sklearn.svm import SVR

model_svr = SVR(kernel='linear')
model_svr.fit(x_train_scaled, y_train)
# Out:
# SVR(kernel='linear')

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# Hyperparameter grid for SVM
param_grid = {
    'C': [0.1, 1.0, 10.0],             # Regularization parameter
    'epsilon': [0.01, 0.1, 0.2],       # Epsilon parameter (controls the margin of tolerance)
    'kernel': ['linear', 'rbf', 'poly'], # Kernel type (linear, RBF, or polynomial)
    'gamma': ['scale', 'auto']         # Kernel coefficient ('scale' is often a good default)
}

# Using GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(SVR(),
                           param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error',
                           n_jobs=-1,
                           verbose=1)

# Fit the grid search
grid_search.fit(x_train_scaled, y_train)

# Best model from grid search
best_svr = grid_search.best_estimator_

# Make predictions with the best model test
y_pred_svr_test = best_svr.predict(x_test_scaled)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits

# %%
# model evaluation measures:(test data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_svr_model=mean_squared_error(y_test,y_pred_svr_test) # MSE
# root mean square error
rmse_svr_model=np.sqrt(mse_svr_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_svr_model=r2_score(y_test,y_pred_svr_test) #R-square


# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_svr_model}")
print(f"RMSE: {rmse_svr_model}")
print(f"R² Score: {r2_svr_model}")
# Out:
# Testing Set Evaluation:
# MSE: 21262444738.729507
# RMSE: 145816.47622518352
# R² Score: 0.10330522007082044

# %%
# adj r2
# adj r2 (test)
adj_r2_svr_model_test=1-(1-r2_svr_model)*((len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1))
adj_r2_svr_model_test
# Out:
# 0.06854960844565838

# %%
# Make predictions with the best model train
y_pred_svr_train = best_svr.predict(x_train_scaled)

# %%
# model evaluation measures:(train data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_svr_model=mean_squared_error(y_train,y_pred_svr_train) # MSE
# root mean square error
rmse_svr_model=np.sqrt(mse_svr_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_svr_model=r2_score(y_train,y_pred_svr_train) #R-square

# adj r2
# adj r2 (test)
adj_r2_svr_model_train=1-(1-r2_svr_model)*((len(y_train)-1)/(len(y_test)-x_train_scaled.shape[1]-1))

# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_svr_model}")
print(f"RMSE: {rmse_svr_model}")
print(f"R² Score: {r2_svr_model}")
print(f"adj_r2:{adj_r2_svr_model_train}")
# Out:
# Testing Set Evaluation:
# MSE: 24262613224.98153
# RMSE: 155764.60838387368
# R² Score: 0.0903975273797697
# adj_r2:-2.7759079386677006

# %%
# 1. Plot: Predictions vs Actual values
plt.figure(figsize=(7, 6))
plt.scatter(y_train, y_pred_svr_train, color='blue')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', lw=2)
plt.title("SVR Model: Predicted vs Actual Values (Training Data)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h3> k-nearist neighbor regressor </h3>

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
# Initilize the lists to store K vslues and corresponding error
k_values=range(1,21)
errors=[]

# %% [markdown]
# #The range 1 to 20 for k_values is commonly used as a starting point because:
# -Practical Size: Most datasets respond well to values of k between 1 and 20. It's a manageable size for experimentation that often includes the "sweet spot."
# -Too Low or High Can Hurt Performance:
# -Low k (like 1): High variance, very sensitive to noise (overfitting).
# -High k (like >20): High bias, model may become too simple and underfit.
# -Computational Efficiency: Trying too many values (e.g., 1 to 100) can be unnecessary and slow, especially on large datasets. So 1–20 is a balanced range for initial tuning.

# %%
k_values
# Out:
# range(1, 21)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Train and evaluate the model for different values of K
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(x_train_scaled, y_train)
    y_pred = knn.predict(x_test_scaled)
    error = mean_squared_error(y_test, y_pred)
    errors.append(error)

# Plot the error curve
plt.figure(figsize=(10, 6))
plt.plot(k_values, errors, marker='o', linestyle='-', color='b')
plt.title('Mean Squared Error for KNN Regressor')
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Mean Squared Error")
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %%
# to find the leasat value of k
optimal_k=k_values[errors.index(min(errors))]
optimal_k
# Out:
# 11

# %%
# train the dataset
knn_optimal=KNeighborsRegressor(n_neighbors=optimal_k)
knn_optimal.fit(x_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=11)

# %%
#predict on the test set
y_pred_knn_test=knn_optimal.predict(x_test_scaled)

# %%
# model evaluation measures:(test data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_knn_model=mean_squared_error(y_test,y_pred_knn_test) # MSE
# root mean square error
rmse_knn_model=np.sqrt(mse_knn_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_knn_model=r2_score(y_test,y_pred_knn_test) #R-square


# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_knn_model}")
print(f"RMSE: {rmse_knn_model}")
print(f"R² Score: {r2_knn_model}")
# Out:
# Testing Set Evaluation:
# MSE: 5211244830.87038
# RMSE: 72188.95227713435
# R² Score: 0.7802277163235741

# %%
# adj r2
# adj r2 (test)
adj_r2_knn_model_test=1-(1-r2_knn_model)*((len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1))
adj_r2_knn_model_test
# Out:
# 0.7717094107547204

# %%
#predict on the train set
y_pred_knn_train=knn_optimal.predict(x_train_scaled)

# %%
# model evaluation measures:(train data)
from sklearn.metrics import mean_squared_error,r2_score
# mean square error(MSE):
mse_knn_model=mean_squared_error(y_train,y_pred_knn_train) # MSE
# root mean square error
rmse_knn_model=np.sqrt(mse_knn_model) #RMS
# coefficient of determine (or) goodness of fit-r2
r2_knn_model=r2_score(y_train,y_pred_knn_train) #R-square


# Print the results
print("Testing Set Evaluation:")
print(f"MSE: {mse_knn_model}")
print(f"RMSE: {rmse_knn_model}")
print(f"R² Score: {r2_knn_model}")
# Out:
# Testing Set Evaluation:
# MSE: 5373706758.0486
# RMSE: 73305.57112558772
# R² Score: 0.7985403753119108

# %%
# adj r2
# adj r2 (train)
adj_r2_knn_model_train=1-(1-r2_knn_model)*((len(y_train)-1)/(len(y_train)-x_train_scaled.shape[1]-1))
adj_r2_knn_model_train
# Out:
# 0.7966416041084415

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h3> MODEL COMPARISON Train </H3>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np

# Dictionary to store results
results = {}

# Dictionary of your trained models
models = {
    "SGD Regressor": sgd_model,
    "KNN (Default)": knn,
    "KNN (Tuned)": knn_optimal,
    "Decision Tree": best_model,
    "Random Forest": best_model_rfr,
    "SVR": best_svr,
    "XGBoost": xgb_model,
    
}

# Evaluate each model on test set
for name, model in models.items():
    y_pred = model.predict(x_train_scaled)
    mae = mean_absolute_error(y_train, y_pred)
    mse = mean_squared_error(y_train, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_train, y_pred)
    
    results[name] = {
        "R² Score": r2,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse
    }

# Display results as a DataFrame
results_df = pd.DataFrame(results).T.sort_values(by="R² Score", ascending=False)
print("\n Model Performance Comparison:")
display(results_df.style.background_gradient(cmap='YlGnBu'))
# Out:
#  Model Performance Comparison:
# <style type="text/css">
# #T_468c2_row0_col0, #T_468c2_row6_col1, #T_468c2_row6_col2, #T_468c2_row6_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_468c2_row0_col1, #T_468c2_row0_col2, #T_468c2_row0_col3, #T_468c2_row6_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_468c2_row1_col0 {
#   background-color: #13266f;
#   color: #f1f1f1;
# }
# #T_468c2_row1_col1 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_468c2_row1_col2 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_468c2_row1_col3 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_468c2_row2_col0 {
#   background-color: #243f99;
#   color: #f1f1f1;
# }
# #T_468c2_row2_col1 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_468c2_row2_col2 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_468c2_row2_col3 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_468c2_row3_col0 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_468c2_row3_col1 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_468c2_row3_col2 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_468c2_row3_col3 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_468c2_row4_col0 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_468c2_row4_col1 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_468c2_row4_col2 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_468c2_row4_col3 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_468c2_row5_col0 {
#   background-color: #2355a4;
#   color: #f1f1f1;
# }
# #T_468c2_row5_col1 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_468c2_row5_col2 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_468c2_row5_col3 {
#   background-color: #80cebb;
#   color: #000000;
# }
# </style>
# <table id="T_468c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_468c2_level0_col0" class="col_heading level0 col0" >R² Score</th>
#       <th id="T_468c2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_468c2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_468c2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_468c2_level0_row0" class="row_heading level0 row0" >XGBoost</th>
#       <td id="T_468c2_row0_col0" class="data row0 col0" >0.956158</td>
#       <td id="T_468c2_row0_col1" class="data row0 col1" >24889.376953</td>
#       <td id="T_468c2_row0_col2" class="data row0 col2" >1169437312.000000</td>
#       <td id="T_468c2_row0_col3" class="data row0 col3" >34197.036597</td>
#     </tr>
#     <tr>
#       <th id="T_468c2_level0_row1" class="row_heading level0 row1" >Random Forest</th>
#       <td id="T_468c2_row1_col0" class="data row1 col0" >0.913273</td>
#       <td id="T_468c2_row1_col1" class="data row1 col1" >36988.699652</td>
#       <td id="T_468c2_row1_col2" class="data row1 col2" >2313352347.604433</td>
#       <td id="T_468c2_row1_col3" class="data row1 col3" >48097.321626</td>
#     </tr>
#     <tr>
#       <th id="T_468c2_level0_row2" class="row_heading level0 row2" >Decision Tree</th>
#       <td id="T_468c2_row2_col0" class="data row2 col0" >0.818964</td>
#       <td id="T_468c2_row2_col1" class="data row2 col1" >53243.910429</td>
#       <td id="T_468c2_row2_col2" class="data row2 col2" >4828932298.264550</td>
#       <td id="T_468c2_row2_col3" class="data row2 col3" >69490.519485</td>
#     </tr>
#     <tr>
#       <th id="T_468c2_level0_row3" class="row_heading level0 row3" >SGD Regressor</th>
#       <td id="T_468c2_row3_col0" class="data row3 col0" >0.815640</td>
#       <td id="T_468c2_row3_col1" class="data row3 col1" >55425.739145</td>
#       <td id="T_468c2_row3_col2" class="data row3 col2" >4917583757.498130</td>
#       <td id="T_468c2_row3_col3" class="data row3 col3" >70125.485792</td>
#     </tr>
#     <tr>
#       <th id="T_468c2_level0_row4" class="row_heading level0 row4" >KNN (Tuned)</th>
#       <td id="T_468c2_row4_col0" class="data row4 col0" >0.798540</td>
#       <td id="T_468c2_row4_col1" class="data row4 col1" >57820.810719</td>
#       <td id="T_468c2_row4_col2" class="data row4 col2" >5373706758.048600</td>
#       <td id="T_468c2_row4_col3" class="data row4 col3" >73305.571126</td>
#     </tr>
#     <tr>
#       <th id="T_468c2_level0_row5" class="row_heading level0 row5" >KNN (Default)</th>
#       <td id="T_468c2_row5_col0" class="data row5 col0" >0.761734</td>
#       <td id="T_468c2_row5_col1" class="data row5 col1" >63168.190299</td>
#       <td id="T_468c2_row5_col2" class="data row5 col2" >6355474323.694030</td>
#       <td id="T_468c2_row5_col3" class="data row5 col3" >79721.228815</td>
#     </tr>
#     <tr>
#       <th id="T_468c2_level0_row6" class="row_heading level0 row6" >SVR</th>
#       <td id="T_468c2_row6_col0" class="data row6 col0" >0.090398</td>
#       <td id="T_468c2_row6_col1" class="data row6 col1" >123906.913805</td>
#       <td id="T_468c2_row6_col2" class="data row6 col2" >24262613224.981529</td>
#       <td id="T_468c2_row6_col3" class="data row6 col3" >155764.608384</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np

# Dictionary to store results
results = {}

# Dictionary of your trained models
models = {
    "SGD Regressor": sgd_model,
    "KNN (Default)": knn,
    "KNN (Tuned)": knn_optimal,
    "Decision Tree":best_model,
    "Random Forest": best_model_rfr,
    "SVR": best_svr,
    "XGBoost": xgb_model,
    
}

# Evaluate each model on test set
for name, model in models.items():
    y_pred = model.predict(x_test_scaled)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    
    results[name] = {
        "R² Score": r2,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse
    }

# Display results as a DataFrame
results_df = pd.DataFrame(results).T.sort_values(by="R² Score", ascending=False)
print("\n Model Performance Comparison:")
display(results_df.style.background_gradient(cmap='YlGnBu'))
# Out:
#  Model Performance Comparison:
# <style type="text/css">
# #T_167c5_row0_col0, #T_167c5_row6_col1, #T_167c5_row6_col2, #T_167c5_row6_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_167c5_row0_col1, #T_167c5_row0_col2, #T_167c5_row0_col3, #T_167c5_row6_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_167c5_row1_col0 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_167c5_row1_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_167c5_row1_col2 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_167c5_row1_col3 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_167c5_row2_col0 {
#   background-color: #0c2060;
#   color: #f1f1f1;
# }
# #T_167c5_row2_col1, #T_167c5_row3_col2 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_167c5_row2_col2 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_167c5_row2_col3 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_167c5_row3_col0 {
#   background-color: #13266f;
#   color: #f1f1f1;
# }
# #T_167c5_row3_col1 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_167c5_row3_col3 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_167c5_row4_col0 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_167c5_row4_col1 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_167c5_row4_col2 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_167c5_row4_col3 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_167c5_row5_col0 {
#   background-color: #22328f;
#   color: #f1f1f1;
# }
# #T_167c5_row5_col1 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_167c5_row5_col2 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_167c5_row5_col3 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# </style>
# <table id="T_167c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_167c5_level0_col0" class="col_heading level0 col0" >R² Score</th>
#       <th id="T_167c5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_167c5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_167c5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_167c5_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_167c5_row0_col0" class="data row0 col0" >0.849530</td>
#       <td id="T_167c5_row0_col1" class="data row0 col1" >45197.745102</td>
#       <td id="T_167c5_row0_col2" class="data row0 col2" >3567942596.386292</td>
#       <td id="T_167c5_row0_col3" class="data row0 col3" >59732.257587</td>
#     </tr>
#     <tr>
#       <th id="T_167c5_level0_row1" class="row_heading level0 row1" >XGBoost</th>
#       <td id="T_167c5_row1_col0" class="data row1 col0" >0.838992</td>
#       <td id="T_167c5_row1_col1" class="data row1 col1" >46816.273438</td>
#       <td id="T_167c5_row1_col2" class="data row1 col2" >3817820672.000000</td>
#       <td id="T_167c5_row1_col3" class="data row1 col3" >61788.515697</td>
#     </tr>
#     <tr>
#       <th id="T_167c5_level0_row2" class="row_heading level0 row2" >SGD Regressor</th>
#       <td id="T_167c5_row2_col0" class="data row2 col0" >0.835378</td>
#       <td id="T_167c5_row2_col1" class="data row2 col1" >48878.916361</td>
#       <td id="T_167c5_row2_col2" class="data row2 col2" >3903519751.096739</td>
#       <td id="T_167c5_row2_col3" class="data row2 col3" >62478.154191</td>
#     </tr>
#     <tr>
#       <th id="T_167c5_level0_row3" class="row_heading level0 row3" >Decision Tree</th>
#       <td id="T_167c5_row3_col0" class="data row3 col0" >0.813082</td>
#       <td id="T_167c5_row3_col1" class="data row3 col1" >52294.447293</td>
#       <td id="T_167c5_row3_col2" class="data row3 col2" >4432207737.106823</td>
#       <td id="T_167c5_row3_col3" class="data row3 col3" >66574.828104</td>
#     </tr>
#     <tr>
#       <th id="T_167c5_level0_row4" class="row_heading level0 row4" >KNN (Tuned)</th>
#       <td id="T_167c5_row4_col0" class="data row4 col0" >0.780228</td>
#       <td id="T_167c5_row4_col1" class="data row4 col1" >57095.640419</td>
#       <td id="T_167c5_row4_col2" class="data row4 col2" >5211244830.870380</td>
#       <td id="T_167c5_row4_col3" class="data row4 col3" >72188.952277</td>
#     </tr>
#     <tr>
#       <th id="T_167c5_level0_row5" class="row_heading level0 row5" >KNN (Default)</th>
#       <td id="T_167c5_row5_col0" class="data row5 col0" >0.763012</td>
#       <td id="T_167c5_row5_col1" class="data row5 col1" >59699.442379</td>
#       <td id="T_167c5_row5_col2" class="data row5 col2" >5619461552.044610</td>
#       <td id="T_167c5_row5_col3" class="data row5 col3" >74963.067920</td>
#     </tr>
#     <tr>
#       <th id="T_167c5_level0_row6" class="row_heading level0 row6" >SVR</th>
#       <td id="T_167c5_row6_col0" class="data row6 col0" >0.103305</td>
#       <td id="T_167c5_row6_col1" class="data row6 col1" >117862.177056</td>
#       <td id="T_167c5_row6_col2" class="data row6 col2" >21262444738.729507</td>
#       <td id="T_167c5_row6_col3" class="data row6 col3" >145816.476225</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <H3> SAVING THE MODEL </H3>

# %%
import pickle

# After training your model:
with open('car_price_rf_model.pkl', 'wb') as f:
    pickle.dump(best_model_rfr, f)

# %% [markdown]
# <h3>Conclusion</h3>
# <h2>Summary of Analysis
# • A regression pipeline was developed and tested.
# • Achieved good results for predicting car prices with linear regression.
# • Model can be improved by using ensemble models or adding external economic factors.
#
#
# Limitations
# • Limited dataset size and scope.
# • Model performance may drop for outlier vehicles or rare configurations.
#
# Suggested Next Steps
# • Implement feature scaling and advanced models.
# • Create a UI tool for price estimation</h2>
